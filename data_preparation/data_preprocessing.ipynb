# %% [markdown]
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes

# %%
import sys
sys.path.append('./EDA.ipynb')

# %%
# %store -r df

# %%
df.shape
# Out:
# (6068, 99)

# %%
df
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                                266            1467                    337
# 1                                233            1395                    326
# 2                                287            1430                    341
# 3                                234            1347                    310
# 4                                250            1585                    372
# ...                              ...             ...                    ...
# 6063                             285            1392                    335
# 6064                             262            1324                    301
# 6065                             260            1334                    318
# 6066                             205            1293                    302
# 6067                             238            1346                    308
#
#       anklecircumference  axillaheight  balloffootcircumference  \
# 0                    222          1347                      253
# 1                    220          1293                      245
# 2                    230          1327                      256
# 3                    230          1239                      262
# 4                    247          1478                      267
# ...                  ...           ...                      ...
# 6063                 223          1297                      252
# 6064                 202          1204                      236
# 6065                 213          1259                      234
# 6066                 199          1207                      213
# 6067                 210          1256                      236
#
#       balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0                  202                401                        369
# 1                  193                394                        338
# 2                  196                427                        408
# 3                  199                401                        359
# 4                  224                435                        356
# ...                ...                ...                        ...
# 6063               196                368                        299
# 6064               181                378                        294
# 6065               183                363                        332
# 6066               163                376                        276
# 6067               188                361                        285
#
#       bicristalbreadth  ...  waistheightomphalion  weightkg  \
# 0                  274  ...                  1054       815
# 1                  257  ...                  1054       726
# 2                  261  ...                  1041       929
# 3                  262  ...                   968       794
# 4                  263  ...                  1245       946
# ...                ...  ...                   ...       ...
# 6063               312  ...                  1002       832
# 6064               287  ...                   958       717
# 6065               299  ...                   970       762
# 6066               280  ...                   952       632
# 6067               279  ...                   943       610
#
#       wristcircumference  wristheight  Gender   DODRace  Age  Heightin  \
# 0                    175          853    Male     White   41        71
# 1                    167          815    Male     White   35        68
# 2                    180          831    Male     Black   42        68
# 3                    176          793    Male     White   31        66
# 4                    188          954    Male     Black   21        77
# ...                  ...          ...     ...       ...  ...       ...
# 6063                 162          836  Female  Hispanic   51        67
# 6064                 157          804  Female  Hispanic   40        63
# 6065                 159          774  Female     Black   40        66
# 6066                 146          769  Female  Hispanic   31        63
# 6067                 154          797  Female  Hispanic   27        66
#
#       Weightlbs  WritingPreference
# 0           180         Right hand
# 1           160          Left hand
# 2           205          Left hand
# 3           175         Right hand
# 4           213         Right hand
# ...         ...                ...
# 6063        180         Right hand
# 6064        150         Right hand
# 6065        168         Right hand
# 6066        133         Right hand
# 6067        132         Right hand
#
# [6068 rows x 99 columns]

# %%
X = df.drop(columns=['DODRace'])
y = df['DODRace']
